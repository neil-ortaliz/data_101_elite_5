# %%
import pandas as pd

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is AE8E-CC45
#
#  Directory of c:\Users\Lenovo\Documents\dlsu\gotta_price_em_all\data_101_elite_5\notebooks
#
# 17/11/2025  06:13 pm    <DIR>          .
# 17/11/2025  06:13 pm    <DIR>          ..
# 17/11/2025  06:13 pm               543 get_portfolio_sample.ipynb
#                1 File(s)            543 bytes
#                2 Dir(s)  380,787,654,656 bytes free

# %%
df = pd.read_csv(r'C:\Users\Lenovo\Documents\dlsu\gotta_price_em_all\data_101_elite_5\pokemon_tcg_dashboard\data\cards_metadata_table.csv', index_col=0)

# %%
portfoliO_df = df.sample(n=20,random_state=42, ignore_index=True)

# %%
portfoliO_df.to_csv(r'C:\Users\Lenovo\Documents\dlsu\gotta_price_em_all\data_101_elite_5\pokemon_tcg_dashboard\data\sample_portfolio_cards_metadata_table.csv')

# %%
import pandas as pd

# %%
metadata_df = pd.read_csv(r'C:\Users\Lenovo\Documents\dlsu\gotta_price_em_all\data_101_elite_5\pokemon_tcg_dashboard\data\cards_metadata_table.csv', index_col=0)

# %%
metadata_df
# Out:
#                             id  tcgPlayerId                     setId  \
# 0     68af6bbbd14a00763202573c       642623  68af37165bce97006df9f23c
# 1     68af6bbbd14a00763202573f       642546  68af37165bce97006df9f23c
# 2     68af6bbbd14a007632025742       642622  68af37165bce97006df9f23c
# 3     68af6bbbd14a007632025745       642621  68af37165bce97006df9f23c
# 4     68af6bbbd14a007632025748       642620  68af37165bce97006df9f23c
# ...                        ...          ...                       ...
# 2668  68af8408c4f780b5153e75f4       497416  68af47bf190c4823de252773
# 2669  68af8408c4f780b5153e75f7       497415  68af47bf190c4823de252773
# 2670  68af8408c4f780b5153e75fa       497414  68af47bf190c4823de252773
# 2671  68af8408c4f780b5153e75fd       497413  68af47bf190c4823de252773
# 2672  68af8408c4f780b5153e7600       497412  68af47bf190c4823de252773
#
#              setName                     name  cardNumber  totalSetNumber  \
# 0         Black Bolt      Zekrom ex - 172/086       172.0            86.0
# 1         Black Bolt        Victini - 171/086       171.0            86.0
# 2         Black Bolt       N's Plan - 170/086       170.0            86.0
# 3         Black Bolt    Genesect ex - 169/086       169.0            86.0
# 4         Black Bolt   Excadrill ex - 168/086       168.0            86.0
# ...              ...                      ...         ...             ...
# 2668  Paldea Evolved  Forretress ex - 005/193         5.0           193.0
# 2669  Paldea Evolved                   Pineco         4.0           193.0
# 2670  Paldea Evolved                 Jumpluff         3.0           193.0
# 2671  Paldea Evolved                 Skiploom         2.0           193.0
# 2672  Paldea Evolved                   Hoppip         1.0           193.0
#
#                          rarity             cardType     hp  ...  \
# 0              Black White Rare            Lightning  230.0  ...
# 1              Black White Rare                 Fire   80.0  ...
# 2     Special Illustration Rare  Trainer - Supporter    NaN  ...
# 3     Special Illustration Rare                Metal  220.0  ...
# 4     Special Illustration Rare             Fighting  270.0  ...
# ...                         ...                  ...    ...  ...
# 2668                Double Rare                Grass  270.0  ...
# 2669                     Common                Grass   70.0  ...
# 2670                       Rare                Grass   90.0  ...
# 2671                   Uncommon                Grass   70.0  ...
# 2672                     Common                Grass   50.0  ...
#
#      prices.variants.Reverse Holofoil.Moderately Played.priceString  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2668                                                NaN
# 2669                                                NaN
# 2670                                                NaN
# 2671                                                NaN
# 2672                                                NaN
#
#       prices.variants.Reverse Holofoil.Damaged.price  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 2668                                             NaN
# 2669                                             NaN
# 2670                                             NaN
# 2671                                             NaN
# 2672                                             NaN
#
#       prices.variants.Reverse Holofoil.Damaged.listings  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2668                                                NaN
# 2669                                                NaN
# 2670                                                NaN
# 2671                                                NaN
# 2672                                                NaN
#
#      prices.variants.Reverse Holofoil.Damaged.priceString  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2668                                                NaN
# 2669                                                NaN
# 2670                                                NaN
# 2671                                                NaN
# 2672                                                NaN
#
#      prices.variants.Normal.Heavily Played.price  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 2668                                         NaN
# 2669                                         NaN
# 2670                                         NaN
# 2671                                         NaN
# 2672                                         NaN
#
#       prices.variants.Normal.Heavily Played.listings  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 2668                                             NaN
# 2669                                             NaN
# 2670                                             NaN
# 2671                                             NaN
# 2672                                             NaN
#
#       prices.variants.Normal.Heavily Played.priceString  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2668                                                NaN
# 2669                                                NaN
# 2670                                                NaN
# 2671                                                NaN
# 2672                                                NaN
#
#      prices.variants.Reverse Holofoil.Heavily Played.price  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2668                                                NaN
# 2669                                                NaN
# 2670                                                NaN
# 2671                                                NaN
# 2672                                                NaN
#
#      prices.variants.Reverse Holofoil.Heavily Played.listings  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2668                                                NaN
# 2669                                                NaN
# 2670                                                NaN
# 2671                                                NaN
# 2672                                                NaN
#
#      prices.variants.Reverse Holofoil.Heavily Played.priceString
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2668                                                NaN
# 2669                                                NaN
# 2670                                                NaN
# 2671                                                NaN
# 2672                                                NaN
#
# [2673 rows x 109 columns]

# %%
price_history_df = pd.read_csv(r'C:\Users\Lenovo\Documents\dlsu\gotta_price_em_all\data_101_elite_5\pokemon_tcg_dashboard\data\price_history.csv', index_col=0)

# %%
price_history_df.head()
# Out:
#                          id  condition                      date  market  \
# 0  68af6bbbd14a00763202573c  Near Mint  2025-07-21T00:00:00.000Z  473.59
# 1  68af6bbbd14a00763202573c  Near Mint  2025-07-28T00:00:00.000Z  465.34
# 2  68af6bbbd14a00763202573c  Near Mint  2025-08-04T00:00:00.000Z  408.64
# 3  68af6bbbd14a00763202573c  Near Mint  2025-08-05T00:00:00.000Z  446.44
# 4  68af6bbbd14a00763202573c  Near Mint  2025-08-06T00:00:00.000Z  433.56
#
#    volume
# 0    19.0
# 1    12.0
# 2    17.0
# 3     4.0
# 4     2.0

# %%
price_history_df=price_history_df.merge(metadata_df[['id', 'tcgPlayerId']], on='id', how='left')

# %%
price_history_df.to_csv(r'C:\Users\Lenovo\Documents\dlsu\gotta_price_em_all\data_101_elite_5\pokemon_tcg_dashboard\data\price_history.csv')

# %%
price_history_df
# Out:
#                               id       condition                      date  \
# 0       68af6bbbd14a00763202573c       Near Mint  2025-07-21T00:00:00.000Z
# 1       68af6bbbd14a00763202573c       Near Mint  2025-07-28T00:00:00.000Z
# 2       68af6bbbd14a00763202573c       Near Mint  2025-08-04T00:00:00.000Z
# 3       68af6bbbd14a00763202573c       Near Mint  2025-08-05T00:00:00.000Z
# 4       68af6bbbd14a00763202573c       Near Mint  2025-08-06T00:00:00.000Z
# ...                          ...             ...                       ...
# 627725  68af8408c4f780b5153e7600  Lightly Played  2025-10-05T00:00:00.000Z
# 627726  68af8408c4f780b5153e7600  Lightly Played  2025-10-06T00:00:00.000Z
# 627727  68af8408c4f780b5153e7600  Lightly Played  2025-10-07T00:00:00.000Z
# 627728  68af8408c4f780b5153e7600  Lightly Played  2025-10-08T00:00:00.000Z
# 627729  68af8408c4f780b5153e7600  Lightly Played  2025-10-09T00:00:00.000Z
#
#         market  volume  tcgPlayerId
# 0       473.59    19.0       642623
# 1       465.34    12.0       642623
# 2       408.64    17.0       642623
# 3       446.44     4.0       642623
# 4       433.56     2.0       642623
# ...        ...     ...          ...
# 627725    0.07     1.0       497412
# 627726    0.07     2.0       497412
# 627727    0.07     NaN       497412
# 627728    0.07     NaN       497412
# 627729    0.07     NaN       497412
#
# [627730 rows x 6 columns]

# %%
price_history_df['tcgPlayerId'] == 497412
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 627725     True
# 627726     True
# 627727     True
# 627728     True
# 627729     True
# Name: tcgPlayerId, Length: 627730, dtype: bool
